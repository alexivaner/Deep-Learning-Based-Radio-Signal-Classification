# %%
import h5py
import numpy as np
import os,random
from tensorflow.keras.layers import Input,Add,Reshape,AveragePooling2D,ZeroPadding2D,BatchNormalization,MaxPool2D,Conv1D,Conv2D,Dropout,Flatten,Dense,Activation,MaxPooling2D,AlphaDropout
from tensorflow.keras import layers
import tensorflow.keras.models as Model
from tensorflow.keras.regularizers import *
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import GlorotUniform as glorot_uniform
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model
import tensorflow_addons as tfa

# %%
f = h5py.File('ExtractDataset/part0.h5')
sample_num = f['X'].shape[0]
# idx = np.random.choice(range(0,sample_num),size=3375)
idx = np.random.choice(range(0,sample_num),size=60000)
X = f['X'][:][idx]
Y = f['Y'][:][idx]
Z = f['Z'][:][idx]
f.close()

for i in range(1,24):
    if i%1 == 0:
        # !free -m
    '''if i == 10:
        continue'''
    filename = 'ExtractDataset/part'+str(i) + '.h5'
    print(filename)
    f = h5py.File(filename,'r')
    X = np.vstack((X,f['X'][:][idx]))
    Y = np.vstack((Y,f['Y'][:][idx]))
    Z = np.vstack((Z,f['Z'][:][idx]))
    f.close()


print('X-size：',X.shape)
print('Y-size：',Y.shape)
print('Z-size：',Z.shape)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   """Entry point for launching an IPython kernel.
#               total        used        free      shared  buff/cache   available
# Mem:          64362        1949       55444          46        6968       61854
# Swap:           976         866         110
# ExtractDataset/part1.h5
#               total        used        free      shared  buff/cache   available
# Mem:          64362        2435       54958          46        6968       61368
# Swap:           976         866         110
# ExtractDataset/part2.h5
#               total        used        free      shared  buff/cache   available
# Mem:          64362        2928       54465          46        6968       60876
# Swap:           976         866         110
# ExtractDataset/part3.h5
#               total        used        free      shared  buff/cache   available
# Mem:          64362        3409       53984          46        6968       60394
# Swap:           976         866         110
# ExtractDataset/part4.h5
#               total        used        free      shared  buff/cache   available
# Mem:          64362        3892       53501          46        6968       59911
# Swap:           976         866         110
# ExtractDataset/part5.h5
#               total        used        free      shared  buff/cache   available
# Mem:          64362        4373       53020          46        6968       59430
# Swap:           976         866         110
# ExtractDataset/part6.h5
#               total        used        free      shared  buff/cache   available
# Mem:          64362        4856       52537          46        6968       58948
# Swap:           976         866         110
# ExtractDataset/part7.h5
#               total        used        free      shared  buff/cache   available
# Mem:          64362        5340       52053          46        6968       58464
# Swap:           976         866         110
# ExtractDataset/part8.h5
#               total        used        free      shared  buff/cache   available
# Mem:          64362        5819       51574          46        6968       57985
# Swap:           976         866         110
# ExtractDataset/part9.h5
#               total        used        free      shared  buff/cache   available
# Mem:          64362        6299       51094          46        6968       57504
# Swap:           976         866         110
# ExtractDataset/part10.h5
#               total        used        free      shared  buff/cache   available
# Mem:          64362        6781       50612          46        6968       57023
# Swap:           976         866         110
# ExtractDataset/part11.h5
#               total        used        free      shared  buff/cache   available
# Mem:          64362        7261       50132          46        6968       56542
# Swap:           976         866         110
# ExtractDataset/part12.h5
#               total        used        free      shared  buff/cache   available
# Mem:          64362        7744       49649          46        6968       56060
# Swap:           976         866         110
# ExtractDataset/part13.h5
#               total        used        free      shared  buff/cache   available
# Mem:          64362        8224       49169          46        6968       55579
# Swap:           976         866         110
# ExtractDataset/part14.h5
#               total        used        free      shared  buff/cache   available
# Mem:          64362        8706       48687          46        6968       55097
# Swap:           976         866         110
# ExtractDataset/part15.h5
#               total        used        free      shared  buff/cache   available
# Mem:          64362        9186       48207          46        6968       54618
# Swap:           976         866         110
# ExtractDataset/part16.h5
#               total        used        free      shared  buff/cache   available
# Mem:          64362        9669       47724          46        6968       54135
# Swap:           976         866         110
# ExtractDataset/part17.h5
#               total        used        free      shared  buff/cache   available
# Mem:          64362       10150       47243          46        6968       53654
# Swap:           976         866         110
# ExtractDataset/part18.h5
#               total        used        free      shared  buff/cache   available
# Mem:          64362       10630       46763          46        6968       53174
# Swap:           976         866         110
# ExtractDataset/part19.h5
#               total        used        free      shared  buff/cache   available
# Mem:          64362       11115       46270          54        6976       52681
# Swap:           976         866         110
# ExtractDataset/part20.h5
#               total        used        free      shared  buff/cache   available
# Mem:          64362       11594       45791          54        6976       52201
# Swap:           976         866         110
# ExtractDataset/part21.h5
#               total        used        free      shared  buff/cache   available
# Mem:          64362       12075       45310          54        6976       51721
# Swap:           976         866         110
# ExtractDataset/part22.h5
#               total        used        free      shared  buff/cache   available
# Mem:          64362       12555       44830          54        6976       51241
# Swap:           976         866         110
# ExtractDataset/part23.h5
# X-size： (1440000, 1024, 2)
# Y-size： (1440000, 24)
# Z-size： (1440000, 1)

# %% [markdown]
# ## Data preprocessing, and obtain training set and test set

# %%
n_examples = X.shape[0]
# n_train = int(n_examples * 0.9877) 
n_train = int(n_examples * 0.8)  
train_idx = np.random.choice(range(0,n_examples), size=n_train, replace=False)  #Randomly select training sample subscript
test_idx = list(set(range(0,n_examples))-set(train_idx)) #Test sample index
X_train = X[train_idx]  #training samples
X_test =  X[test_idx]  #testing samples
Y_train = Y[train_idx]
Y_test = Y[test_idx]
print("X_train:",X_train.shape)
print("Y_train:",Y_train.shape)
print("X_test:",X_test.shape)
print("Y_test:",Y_test.shape)
# Out:
# X_train: (1152000, 1024, 2)
# Y_train: (1152000, 24)
# X_test: (288000, 1024, 2)
# Y_test: (288000, 24)

# %%
X_train[0]
# Out:
# array([[-0.7175385 , -1.2539217 ],
#        [-1.0807455 ,  0.03369522],
#        [ 0.28000197, -2.674733  ],
#        ...,
#        [-0.13295494,  0.26090968],
#        [ 0.03728972, -0.16332997],
#        [ 0.04874938,  0.3179658 ]], dtype=float32)

# %%
X_train.shape[1:] 
# Input(in_shp)
# Out:
# (1024, 2)

# %%
units = round((X_train.shape[0])/(0.2*(X_train.shape[1]+X_train.shape[2])))
units/7
# Out:
# 802.0

# %%
# #FULL RESNET
# def identity_block(X, f, filters, stage, block):
#     """
#     Implementation of the identity block as defined in Figure 3
    
#     Arguments:
#     X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
#     f -- integer, specifying the shape of the middle CONV's window for the main path
#     filters -- python list of integers, defining the number of filters in the CONV layers of the main path
#     stage -- integer, used to name the layers, depending on their position in the network
#     block -- string/character, used to name the layers, depending on their position in the network
    
#     Returns:
#     X -- output of the identity block, tensor of shape (n_H, n_W, n_C)
#     """
    
#     # defining name basis
#     conv_name_base = 'res' + str(stage) + block + '_branch'
#     bn_name_base = 'bn' + str(stage) + block + '_branch'
    
#     # Retrieve Filters
#     F1, F2, F3 = filters
    
#     # Save the input value. You'll need this later to add back to the main path. 
#     X_shortcut = X
    
#     # First component of main path
#     X = Conv2D(filters = F1, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0),data_format="channels_first")(X)
#     X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
#     X = Activation('relu')(X)

    
#     # Second component of main path (≈3 lines)
#     X = Conv2D(filters = F2, kernel_size = (f, f), strides = (1,1), padding = 'same', name = conv_name_base + '2b', kernel_initializer = glorot_uniform(seed=0),data_format="channels_first")(X)
#     X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
#     X = Activation('relu')(X)

#     # Third component of main path (≈2 lines)
#     X = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed=0),data_format="channels_first")(X)
#     X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)

#     # Final step: Add shortcut value to main path, and pass it through a RELU activation (≈2 lines)
#     X = Add()([X, X_shortcut])
#     X = Activation('relu')(X)
    
    
#     return X

# def convolutional_block(X, f, filters, stage, block, s = 2):

#     """
#     Implementation of the convolutional block as defined in Figure 4
    
#     Arguments:
#     X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
#     f -- integer, specifying the shape of the middle CONV's window for the main path
#     filters -- python list of integers, defining the number of filters in the CONV layers of the main path
#     stage -- integer, used to name the layers, depending on their position in the network
#     block -- string/character, used to name the layers, depending on their position in the network
#     s -- Integer, specifying the stride to be used
    
#     Returns:
#     X -- output of the convolutional block, tensor of shape (n_H, n_W, n_C)
#     """
    
#     # defining name basis
#     conv_name_base = 'res' + str(stage) + block + '_branch'
#     bn_name_base = 'bn' + str(stage) + block + '_branch'
    
#     # Retrieve Filters
#     F1, F2, F3 = filters
    
#     # Save the input value
#     X_shortcut = X


#     ##### MAIN PATH #####
#     # First component of main path 
#     X = Conv2D(F1, (1, 1), strides = (s,s), name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0),data_format="channels_first")(X)
#     X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
#     X = Activation('relu')(X)

#     # Second component of main path (≈3 lines)
#     X = Conv2D(filters = F2, kernel_size = (f, f), strides = (1,1), padding = 'same', name = conv_name_base + '2b', kernel_initializer = glorot_uniform(seed=0),data_format="channels_first")(X)
#     X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
#     X = Activation('relu')(X)


#     # Third component of main path (≈2 lines)
#     X = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed=0),data_format="channels_first")(X)
#     X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)


#     ##### SHORTCUT PATH #### (≈2 lines)
#     X_shortcut = Conv2D(filters = F3, kernel_size = (1, 1), strides = (s,s), padding = 'valid', name = conv_name_base + '1',
#                         kernel_initializer = glorot_uniform(seed=0),data_format="channels_first")(X_shortcut)
#     X_shortcut = BatchNormalization(axis = 3, name = bn_name_base + '1')(X_shortcut)

#     # Final step: Add shortcut value to main path, and pass it through a RELU activation (≈2 lines)
#     X = Add()([X, X_shortcut])
#     X = Activation('relu')(X)
    
    
#     return X

# def ResNet50(input_shape=(64, 64, 3), classes=6):
#     """
#     Implementation of the popular ResNet50 the following architecture:
#     CONV2D -> BATCHNORM -> RELU -> MAXPOOL -> CONVBLOCK -> IDBLOCK*2 -> CONVBLOCK -> IDBLOCK*3
#     -> CONVBLOCK -> IDBLOCK*5 -> CONVBLOCK -> IDBLOCK*2 -> AVGPOOL -> TOPLAYER

#     Arguments:
#     input_shape -- shape of the images of the dataset
#     classes -- integer, number of classes

#     Returns:
#     model -- a Model() instance in Keras
#     """
#     mirrored_strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0","/gpu:1","/gpu:2"], cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())
#     with mirrored_strategy.scope():
#         # Define the input as a tensor with shape input_shape
#         X_input = Input(input_shape)
#         X = Reshape([1,1024,2], input_shape=in_shp)(X_input)

#         # Zero-Padding
#         X = ZeroPadding2D((3, 3))(X)

#         # Stage 1
#         X = Conv2D(64, (7, 7), strides=(2, 2), name='conv1', kernel_initializer=glorot_uniform(seed=0))(X)
#         X = BatchNormalization(axis=3, name='bn_conv1')(X)
#         X = Activation('relu')(X)
#         X = MaxPooling2D((3, 3), strides=(2, 2),data_format="channels_first")(X)

#         # Stage 2
#         X = convolutional_block(X, f=3, filters=[64, 64, 256], stage=2, block='a', s=1)
#         X = identity_block(X, 3, [64, 64, 256], stage=2, block='b')
#         X = identity_block(X, 3, [64, 64, 256], stage=2, block='c')

#         ### START CODE HERE ###

#         # Stage 3 (≈4 lines)
#         X = convolutional_block(X, f = 3, filters = [128, 128, 512], stage = 3, block='a', s = 2)
#         X = identity_block(X, 3, [128, 128, 512], stage=3, block='b')
#         X = identity_block(X, 3, [128, 128, 512], stage=3, block='c')
#         X = identity_block(X, 3, [128, 128, 512], stage=3, block='d')

#         # Stage 4 (≈6 lines)
#         X = convolutional_block(X, f = 3, filters = [256, 256, 1024], stage = 4, block='a', s = 2)
#         X = identity_block(X, 3, [256, 256, 1024], stage=4, block='b')
#         X = identity_block(X, 3, [256, 256, 1024], stage=4, block='c')
#         X = identity_block(X, 3, [256, 256, 1024], stage=4, block='d')
#         X = identity_block(X, 3, [256, 256, 1024], stage=4, block='e')
#         X = identity_block(X, 3, [256, 256, 1024], stage=4, block='f')

#         # Stage 5 (≈3 lines)
#         X = convolutional_block(X, f = 3, filters = [512, 512, 2048], stage = 5, block='a', s = 2)
#         X = identity_block(X, 3, [512, 512, 2048], stage=5, block='b')
#         X = identity_block(X, 3, [512, 512, 2048], stage=5, block='c')

#         # AVGPOOL (≈1 line). Use "X = AveragePooling2D(...)(X)"
#         X = AveragePooling2D((2,2), name="avg_pool")(X)

#         ### END CODE HERE ###

#         # output layer
#         X = Flatten()(X)
#         X = Dense(classes, activation='softmax', name='fc' + str(classes), kernel_initializer = glorot_uniform(seed=0))(X)


#         # Create model
#         model = Model.Model(inputs = X_input, outputs = X, name='ResNet50')

#     return model

# %%
# classes = ['32PSK',
#  '16APSK',
#  '32QAM',
#  'FM',
#  'GMSK',
#  '32APSK',
#  'OQPSK',
#  '8ASK',
#  'BPSK',
#  '8PSK',
#  'AM-SSB-SC',
#  '4ASK',
#  '16PSK',
#  '64APSK',
#  '128QAM',
#  '128APSK',
#  'AM-DSB-SC',
#  'AM-SSB-WC',
#  '64QAM',
#  'QPSK',
#  '256QAM',
#  'AM-DSB-WC',
#  'OOK',
#  '16QAM']

   
# in_shp = X_train.shape[1:]   #Dimensions of each sample
# model = ResNet50(input_shape = in_shp, classes = 24)
# model.compile(loss='categorical_crossentropy', optimizer=tfa.optimizers.LazyAdam(),metrics=['accuracy'])
# model.summary()

# %%
classes = ['32PSK',
 '16APSK',
 '32QAM',
 'FM',
 'GMSK',
 '32APSK',
 'OQPSK',
 '8ASK',
 'BPSK',
 '8PSK',
 'AM-SSB-SC',
 '4ASK',
 '16PSK',
 '64APSK',
 '128QAM',
 '128APSK',
 'AM-DSB-SC',
 'AM-SSB-WC',
 '64QAM',
 'QPSK',
 '256QAM',
 'AM-DSB-WC',
 'OOK',
 '16QAM']

   
def residual_stack(X,Filters,Seq,max_pool):
    #1*1 Conv Linear
    X = Conv2D(Filters, (1, 1), padding='same', name=Seq+"_conv1", kernel_initializer='glorot_uniform',data_format="channels_first")(X)
    X = BatchNormalization(axis = 3)(X)

    #Residual Unit 1
    X_shortcut = X
    X = Conv2D(Filters, (3, 2), padding='same',activation="relu",name=Seq+"_conv2", kernel_initializer='glorot_uniform',data_format="channels_first")(X)
    X = Conv2D(Filters, (3, 2), padding='same', name=Seq+"_conv3", kernel_initializer='glorot_uniform',data_format="channels_first")(X)
    X = BatchNormalization(axis = 3)(X)

    X = layers.add([X,X_shortcut])
    X = Activation("relu")(X)
    #Residual Unit 2
    X_shortcut = X
    X = Conv2D(Filters, (3, 2), padding='same',activation="relu",name=Seq+"_conv4", kernel_initializer='glorot_uniform',data_format="channels_first")(X)
    X = Conv2D(Filters, (3, 2), padding='same', name=Seq+"_conv5", kernel_initializer='glorot_uniform',data_format="channels_first")(X)
    X = BatchNormalization(axis = 3)(X)

    
    X = layers.add([X,X_shortcut])
    X = Activation("relu")(X)
    #MaxPooling
    if max_pool:
        X = MaxPooling2D(pool_size=(2, 1), strides=(2, 1), padding='valid', data_format="channels_first")(X)
    return X

mirrored_strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0","/gpu:1","/gpu:2"], cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

with mirrored_strategy.scope():
    in_shp = X_train.shape[1:]   #Dimensions of each sample
    #input layer
    X_input = Input(in_shp)
    X = Reshape([1,1024,2], input_shape=in_shp)(X_input)
    #Residual Srack 1
    X = residual_stack(X,32,"ReStk1",False)  #shape:(1,512,32)
    X = MaxPooling2D(pool_size=(2, 2), strides=(2, 1), padding='valid', data_format="channels_first")(X)
    #Residual Srack 2
    X = residual_stack(X,32,"ReStk2",True)  #shape:(1,256,32)
    #Residual Srack 3
    X = residual_stack(X,64,"ReStk3",True)  #shape:(1,128,32)
    #Residual Srack 4
    X = residual_stack(X,64,"ReStk4",True)  #shape:(1,64,32)
    #Residual Srack 5
    # X = residual_stack(X,32,"ReStk5",True)  #shape:(1,32,32)
    # #Residual Srack 6
    # X = residual_stack(X,32,"ReStk6",True)  #shape:(1,16,32)
    #Full Con 1
    X = Flatten()(X)
    X = Dense(128, activation='selu', kernel_initializer='he_normal', name="dense1")(X)
    X = Dropout(0.3)(X)
    #Full Con 2
    X = Dense(128, activation='selu', kernel_initializer='he_normal', name="dense2")(X)
    X = Dropout(0.3)(X)
    #Full Con 3
    X = Dense(len(classes), kernel_initializer='he_normal', name="dense3")(X)
    #SoftMax
    X = Activation('softmax')(X)
    #Create Model
    model = Model.Model(inputs=X_input,outputs=X)
    
model.compile(loss='categorical_crossentropy', optimizer=tfa.optimizers.LazyAdam(),metrics=['accuracy'])
model.summary()
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2')
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 1024, 2)]    0
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 1024, 2)   0           input_1[0][0]
# __________________________________________________________________________________________________
# ReStk1_conv1 (Conv2D)           (None, 32, 1024, 2)  64          reshape[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 1024, 2)  8           ReStk1_conv1[0][0]
# __________________________________________________________________________________________________
# ReStk1_conv2 (Conv2D)           (None, 32, 1024, 2)  6176        batch_normalization[0][0]
# __________________________________________________________________________________________________
# ReStk1_conv3 (Conv2D)           (None, 32, 1024, 2)  6176        ReStk1_conv2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 1024, 2)  8           ReStk1_conv3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 1024, 2)  0           batch_normalization_1[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 1024, 2)  0           add[0][0]
# __________________________________________________________________________________________________
# ReStk1_conv4 (Conv2D)           (None, 32, 1024, 2)  6176        activation[0][0]
# __________________________________________________________________________________________________
# ReStk1_conv5 (Conv2D)           (None, 32, 1024, 2)  6176        ReStk1_conv4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 1024, 2)  8           ReStk1_conv5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 1024, 2)  0           batch_normalization_2[0][0]
#                                                                  activation[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 1024, 2)  0           add_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 32, 512, 1)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# ReStk2_conv1 (Conv2D)           (None, 32, 512, 1)   1056        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 512, 1)   4           ReStk2_conv1[0][0]
# __________________________________________________________________________________________________
# ReStk2_conv2 (Conv2D)           (None, 32, 512, 1)   6176        batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# ReStk2_conv3 (Conv2D)           (None, 32, 512, 1)   6176        ReStk2_conv2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 512, 1)   4           ReStk2_conv3[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 512, 1)   0           batch_normalization_4[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 512, 1)   0           add_2[0][0]
# __________________________________________________________________________________________________
# ReStk2_conv4 (Conv2D)           (None, 32, 512, 1)   6176        activation_2[0][0]
# __________________________________________________________________________________________________
# ReStk2_conv5 (Conv2D)           (None, 32, 512, 1)   6176        ReStk2_conv4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 512, 1)   4           ReStk2_conv5[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 512, 1)   0           batch_normalization_5[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 512, 1)   0           add_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 256, 1)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# ReStk3_conv1 (Conv2D)           (None, 64, 256, 1)   2112        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 256, 1)   4           ReStk3_conv1[0][0]
# __________________________________________________________________________________________________
# ReStk3_conv2 (Conv2D)           (None, 64, 256, 1)   24640       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# ReStk3_conv3 (Conv2D)           (None, 64, 256, 1)   24640       ReStk3_conv2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64, 256, 1)   4           ReStk3_conv3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 64, 256, 1)   0           batch_normalization_7[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 256, 1)   0           add_4[0][0]
# __________________________________________________________________________________________________
# ReStk3_conv4 (Conv2D)           (None, 64, 256, 1)   24640       activation_4[0][0]
# __________________________________________________________________________________________________
# ReStk3_conv5 (Conv2D)           (None, 64, 256, 1)   24640       ReStk3_conv4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64, 256, 1)   4           ReStk3_conv5[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 64, 256, 1)   0           batch_normalization_8[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 256, 1)   0           add_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 128, 1)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# ReStk4_conv1 (Conv2D)           (None, 64, 128, 1)   4160        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 64, 128, 1)   4           ReStk4_conv1[0][0]
# __________________________________________________________________________________________________
# ReStk4_conv2 (Conv2D)           (None, 64, 128, 1)   24640       batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# ReStk4_conv3 (Conv2D)           (None, 64, 128, 1)   24640       ReStk4_conv2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 64, 128, 1)   4           ReStk4_conv3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 64, 128, 1)   0           batch_normalization_10[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 128, 1)   0           add_6[0][0]
# __________________________________________________________________________________________________
# ReStk4_conv4 (Conv2D)           (None, 64, 128, 1)   24640       activation_6[0][0]
# __________________________________________________________________________________________________
# ReStk4_conv5 (Conv2D)           (None, 64, 128, 1)   24640       ReStk4_conv4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 64, 128, 1)   4           ReStk4_conv5[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 64, 128, 1)   0           batch_normalization_11[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64, 128, 1)   0           add_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 64, 64, 1)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 4096)         0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 128)          524416      flatten[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128)          0           dense1[0][0]
# __________________________________________________________________________________________________
# dense2 (Dense)                  (None, 128)          16512       dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128)          0           dense2[0][0]
# __________________________________________________________________________________________________
# dense3 (Dense)                  (None, 24)           3096        dropout_1[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 24)           0           dense3[0][0]
# ==================================================================================================
# Total params: 798,004
# Trainable params: 797,974
# Non-trainable params: 30
# __________________________________________________________________________________________________

# %%
# from tensorflow.keras.utils import plot_model
# plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
# %%time
filepath = 'resnet2_model.h5'
history = model.fit(X_train,
    Y_train,
    batch_size=1024,
    epochs=100,
    verbose=1,
#     validation_data=(X_test, Y_test),
    validation_split = 0.2,
    callbacks = [
        tf.keras.callbacks.ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='auto'),
        tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='auto')
    ])
# Out:
# Epoch 1/100
# 900/900 [==============================] - ETA: 0s - loss: 2.4044 - accuracy: 0.2151
# Epoch 00001: val_loss improved from inf to 2.16860, saving model to resnet2_model.h5
# 900/900 [==============================] - 161s 179ms/step - loss: 2.4044 - accuracy: 0.2151 - val_loss: 2.1686 - val_accuracy: 0.2593
# Epoch 2/100
# 900/900 [==============================] - ETA: 0s - loss: 1.8118 - accuracy: 0.3770
# Epoch 00002: val_loss improved from 2.16860 to 1.78434, saving model to resnet2_model.h5
# 900/900 [==============================] - 162s 180ms/step - loss: 1.8118 - accuracy: 0.3770 - val_loss: 1.7843 - val_accuracy: 0.3856
# Epoch 3/100
# 900/900 [==============================] - ETA: 0s - loss: 1.7005 - accuracy: 0.4176
# Epoch 00003: val_loss did not improve from 1.78434
# 900/900 [==============================] - 163s 181ms/step - loss: 1.7005 - accuracy: 0.4176 - val_loss: 1.8837 - val_accuracy: 0.3576
# Epoch 4/100
# 900/900 [==============================] - ETA: 0s - loss: 1.5910 - accuracy: 0.4515
# Epoch 00004: val_loss improved from 1.78434 to 1.53857, saving model to resnet2_model.h5
# 900/900 [==============================] - 164s 182ms/step - loss: 1.5910 - accuracy: 0.4515 - val_loss: 1.5386 - val_accuracy: 0.4681
# Epoch 5/100
# 900/900 [==============================] - ETA: 0s - loss: 1.5116 - accuracy: 0.4790
# Epoch 00005: val_loss did not improve from 1.53857
# 900/900 [==============================] - 164s 182ms/step - loss: 1.5116 - accuracy: 0.4790 - val_loss: 1.5750 - val_accuracy: 0.4592
# Epoch 6/100
# 900/900 [==============================] - ETA: 0s - loss: 1.4446 - accuracy: 0.5071
# Epoch 00006: val_loss improved from 1.53857 to 1.39436, saving model to resnet2_model.h5
# 900/900 [==============================] - 164s 182ms/step - loss: 1.4446 - accuracy: 0.5071 - val_loss: 1.3944 - val_accuracy: 0.5239
# Epoch 7/100
# 900/900 [==============================] - ETA: 0s - loss: 1.4020 - accuracy: 0.5243
# Epoch 00007: val_loss did not improve from 1.39436
# 900/900 [==============================] - 164s 183ms/step - loss: 1.4020 - accuracy: 0.5243 - val_loss: 1.4043 - val_accuracy: 0.5200
# Epoch 8/100
# 900/900 [==============================] - ETA: 0s - loss: 1.3733 - accuracy: 0.5360
# Epoch 00008: val_loss improved from 1.39436 to 1.34487, saving model to resnet2_model.h5
# 900/900 [==============================] - 165s 183ms/step - loss: 1.3733 - accuracy: 0.5360 - val_loss: 1.3449 - val_accuracy: 0.5484
# Epoch 9/100
# 900/900 [==============================] - ETA: 0s - loss: 1.3491 - accuracy: 0.5466
# Epoch 00009: val_loss did not improve from 1.34487
# 900/900 [==============================] - 165s 183ms/step - loss: 1.3491 - accuracy: 0.5466 - val_loss: 1.3468 - val_accuracy: 0.5504
# Epoch 10/100
# 900/900 [==============================] - ETA: 0s - loss: 1.3324 - accuracy: 0.5553
# Epoch 00010: val_loss improved from 1.34487 to 1.32136, saving model to resnet2_model.h5
# 900/900 [==============================] - 165s 183ms/step - loss: 1.3324 - accuracy: 0.5553 - val_loss: 1.3214 - val_accuracy: 0.5587
# Epoch 11/100
# 900/900 [==============================] - ETA: 0s - loss: 1.3089 - accuracy: 0.5666
# Epoch 00011: val_loss improved from 1.32136 to 1.31982, saving model to resnet2_model.h5
# 900/900 [==============================] - 165s 183ms/step - loss: 1.3089 - accuracy: 0.5666 - val_loss: 1.3198 - val_accuracy: 0.5646
# Epoch 12/100
# 900/900 [==============================] - ETA: 0s - loss: 1.2952 - accuracy: 0.5722
# Epoch 00012: val_loss improved from 1.31982 to 1.30507, saving model to resnet2_model.h5
# 900/900 [==============================] - 165s 183ms/step - loss: 1.2952 - accuracy: 0.5722 - val_loss: 1.3051 - val_accuracy: 0.5672
# Epoch 13/100
# 900/900 [==============================] - ETA: 0s - loss: 1.2811 - accuracy: 0.5774
# Epoch 00013: val_loss did not improve from 1.30507
# 900/900 [==============================] - 165s 183ms/step - loss: 1.2811 - accuracy: 0.5774 - val_loss: 1.3178 - val_accuracy: 0.5630
# Epoch 14/100
# 900/900 [==============================] - ETA: 0s - loss: 1.2739 - accuracy: 0.5809
# Epoch 00014: val_loss improved from 1.30507 to 1.28247, saving model to resnet2_model.h5
# 900/900 [==============================] - 165s 184ms/step - loss: 1.2739 - accuracy: 0.5809 - val_loss: 1.2825 - val_accuracy: 0.5773
# Epoch 15/100
# 900/900 [==============================] - ETA: 0s - loss: 1.2663 - accuracy: 0.5843
# Epoch 00015: val_loss did not improve from 1.28247
# 900/900 [==============================] - 165s 184ms/step - loss: 1.2663 - accuracy: 0.5843 - val_loss: 1.3267 - val_accuracy: 0.5640
# Epoch 16/100
# 900/900 [==============================] - ETA: 0s - loss: 1.2504 - accuracy: 0.5905
# Epoch 00016: val_loss improved from 1.28247 to 1.25505, saving model to resnet2_model.h5
# 900/900 [==============================] - 165s 184ms/step - loss: 1.2504 - accuracy: 0.5905 - val_loss: 1.2550 - val_accuracy: 0.5862
# Epoch 17/100
# 900/900 [==============================] - ETA: 0s - loss: 1.2479 - accuracy: 0.5918
# Epoch 00017: val_loss improved from 1.25505 to 1.25414, saving model to resnet2_model.h5
# 900/900 [==============================] - 165s 184ms/step - loss: 1.2479 - accuracy: 0.5918 - val_loss: 1.2541 - val_accuracy: 0.5884
# Epoch 18/100
# 900/900 [==============================] - ETA: 0s - loss: 1.2523 - accuracy: 0.5899
# Epoch 00018: val_loss did not improve from 1.25414
# 900/900 [==============================] - 165s 184ms/step - loss: 1.2523 - accuracy: 0.5899 - val_loss: 1.3500 - val_accuracy: 0.5585
# Epoch 19/100
# 900/900 [==============================] - ETA: 0s - loss: 1.2296 - accuracy: 0.5995
# Epoch 00019: val_loss did not improve from 1.25414
# 900/900 [==============================] - 165s 184ms/step - loss: 1.2296 - accuracy: 0.5995 - val_loss: 1.2976 - val_accuracy: 0.5759
# Epoch 20/100
# 900/900 [==============================] - ETA: 0s - loss: 1.2242 - accuracy: 0.6017
# Epoch 00020: val_loss did not improve from 1.25414
# 900/900 [==============================] - 165s 184ms/step - loss: 1.2242 - accuracy: 0.6017 - val_loss: 1.4170 - val_accuracy: 0.5453
# Epoch 21/100
# 900/900 [==============================] - ETA: 0s - loss: 1.2192 - accuracy: 0.6043
# Epoch 00021: val_loss did not improve from 1.25414
# 900/900 [==============================] - 165s 184ms/step - loss: 1.2192 - accuracy: 0.6043 - val_loss: 1.3307 - val_accuracy: 0.5697
# Epoch 22/100
# 900/900 [==============================] - ETA: 0s - loss: 1.2143 - accuracy: 0.6065
# Epoch 00022: val_loss did not improve from 1.25414
# 900/900 [==============================] - 165s 184ms/step - loss: 1.2143 - accuracy: 0.6065 - val_loss: 1.2605 - val_accuracy: 0.5899
# Epoch 23/100
# 900/900 [==============================] - ETA: 0s - loss: 1.2230 - accuracy: 0.6032
# Epoch 00023: val_loss improved from 1.25414 to 1.22660, saving model to resnet2_model.h5
# 900/900 [==============================] - 165s 184ms/step - loss: 1.2230 - accuracy: 0.6032 - val_loss: 1.2266 - val_accuracy: 0.6028
# Epoch 24/100
# 900/900 [==============================] - ETA: 0s - loss: 1.2012 - accuracy: 0.6116
# Epoch 00024: val_loss improved from 1.22660 to 1.22334, saving model to resnet2_model.h5
# 900/900 [==============================] - 166s 184ms/step - loss: 1.2012 - accuracy: 0.6116 - val_loss: 1.2233 - val_accuracy: 0.6034
# Epoch 25/100
# 900/900 [==============================] - ETA: 0s - loss: 1.1974 - accuracy: 0.6134
# Epoch 00025: val_loss did not improve from 1.22334
# 900/900 [==============================] - 165s 184ms/step - loss: 1.1974 - accuracy: 0.6134 - val_loss: 1.2531 - val_accuracy: 0.5920
# Epoch 26/100
# 900/900 [==============================] - ETA: 0s - loss: 1.1926 - accuracy: 0.6153
# Epoch 00026: val_loss did not improve from 1.22334
# 900/900 [==============================] - 165s 184ms/step - loss: 1.1926 - accuracy: 0.6153 - val_loss: 1.2760 - val_accuracy: 0.5861
# Epoch 27/100
# 900/900 [==============================] - ETA: 0s - loss: 1.1876 - accuracy: 0.6178
# Epoch 00027: val_loss did not improve from 1.22334
# 900/900 [==============================] - 165s 184ms/step - loss: 1.1876 - accuracy: 0.6178 - val_loss: 1.2552 - val_accuracy: 0.5940
# Epoch 28/100
# 900/900 [==============================] - ETA: 0s - loss: 1.1878 - accuracy: 0.6176
# Epoch 00028: val_loss improved from 1.22334 to 1.22077, saving model to resnet2_model.h5
# 900/900 [==============================] - 166s 184ms/step - loss: 1.1878 - accuracy: 0.6176 - val_loss: 1.2208 - val_accuracy: 0.6051
# Epoch 29/100
# 900/900 [==============================] - ETA: 0s - loss: 1.1780 - accuracy: 0.6215
# Epoch 00029: val_loss did not improve from 1.22077
# 900/900 [==============================] - 166s 184ms/step - loss: 1.1780 - accuracy: 0.6215 - val_loss: 1.2611 - val_accuracy: 0.5945
# Epoch 30/100
# 900/900 [==============================] - ETA: 0s - loss: 1.1744 - accuracy: 0.6228
# Epoch 00030: val_loss did not improve from 1.22077
# 900/900 [==============================] - 166s 184ms/step - loss: 1.1744 - accuracy: 0.6228 - val_loss: 1.2383 - val_accuracy: 0.6010
# Epoch 31/100
# 900/900 [==============================] - ETA: 0s - loss: 1.1711 - accuracy: 0.6249
# Epoch 00031: val_loss did not improve from 1.22077
# 900/900 [==============================] - 166s 184ms/step - loss: 1.1711 - accuracy: 0.6249 - val_loss: 1.2653 - val_accuracy: 0.5920
# Epoch 32/100
# 900/900 [==============================] - ETA: 0s - loss: 1.1658 - accuracy: 0.6272
# Epoch 00032: val_loss did not improve from 1.22077
# 900/900 [==============================] - 166s 184ms/step - loss: 1.1658 - accuracy: 0.6272 - val_loss: 1.2584 - val_accuracy: 0.5993
# Epoch 33/100
# 900/900 [==============================] - ETA: 0s - loss: 1.1624 - accuracy: 0.6279
# Epoch 00033: val_loss did not improve from 1.22077
# 900/900 [==============================] - 165s 184ms/step - loss: 1.1624 - accuracy: 0.6279 - val_loss: 1.2279 - val_accuracy: 0.6054
# Epoch 34/100
# 900/900 [==============================] - ETA: 0s - loss: 1.1583 - accuracy: 0.6301
# Epoch 00034: val_loss did not improve from 1.22077
# 900/900 [==============================] - 166s 184ms/step - loss: 1.1583 - accuracy: 0.6301 - val_loss: 1.3185 - val_accuracy: 0.5811
# Epoch 35/100
# 900/900 [==============================] - ETA: 0s - loss: 1.1542 - accuracy: 0.6314
# Epoch 00035: val_loss did not improve from 1.22077
# 900/900 [==============================] - 166s 184ms/step - loss: 1.1542 - accuracy: 0.6314 - val_loss: 1.2375 - val_accuracy: 0.6071
# Epoch 36/100
# 900/900 [==============================] - ETA: 0s - loss: 1.1516 - accuracy: 0.6331
# Epoch 00036: val_loss did not improve from 1.22077
# 900/900 [==============================] - 166s 184ms/step - loss: 1.1516 - accuracy: 0.6331 - val_loss: 1.2832 - val_accuracy: 0.5913
# Epoch 37/100
# 900/900 [==============================] - ETA: 0s - loss: 1.1497 - accuracy: 0.6330
# Epoch 00037: val_loss did not improve from 1.22077
# 900/900 [==============================] - 166s 184ms/step - loss: 1.1497 - accuracy: 0.6330 - val_loss: 1.2336 - val_accuracy: 0.6076
# Epoch 38/100
# 900/900 [==============================] - ETA: 0s - loss: 1.1425 - accuracy: 0.6367
# Epoch 00038: val_loss did not improve from 1.22077
# 900/900 [==============================] - 166s 184ms/step - loss: 1.1425 - accuracy: 0.6367 - val_loss: 1.2372 - val_accuracy: 0.6055
# Epoch 00038: early stopping
# CPU times: user 50min 4s, sys: 5min 22s, total: 55min 26s
# Wall time: 1h 44min 40s

# %%
fig, ((ax1, ax2)) = plt.subplots(nrows=1, ncols=2,figsize=(20,6))

ax1.plot(history.history['accuracy'],'b', history.history['val_accuracy'], 'r')
ax1.set_ylabel('Accuracy Rate',fontsize=12)
ax1.set_xlabel('Iteration',fontsize=12)
ax1.set_title('Categorical Cross Entropy ',fontsize=14)
ax1.legend(['Training Accuracy','Validation Accuracy'],fontsize=12,loc='best')

ax2.plot(history.history['loss'], 'b',history.history['val_loss'],'r')
ax2.set_ylabel('Loss',fontsize=12)
ax2.set_xlabel('Iteration',fontsize=12)
ax2.set_title('Learning Curve ',fontsize=14)
ax2.legend(['Training Loss','Validation Loss'],fontsize=12,loc='best')

# plt.savefig('crosse_results.png')
plt.show()

# %%
model = load_model(filepath)

# %%
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues, labels=[]):
    plt.figure(figsize=(10, 10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(labels))
    plt.xticks(tick_marks, labels, rotation=45)
    plt.yticks(tick_marks, labels)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
# Plot confusion matrix
batch_size = 1024
test_Y_hat = model.predict(X_test, batch_size=3000)
conf = np.zeros([len(classes),len(classes)])
confnorm = np.zeros([len(classes),len(classes)])
for i in range(0,X_test.shape[0]):
    j = list(Y_test[i,:]).index(1)
    k = int(np.argmax(test_Y_hat[i,:]))
    conf[j,k] = conf[j,k] + 1
for i in range(0,len(classes)):
    confnorm[i,:] = conf[i,:] / np.sum(conf[i,:])
plot_confusion_matrix(confnorm, labels=classes)

# %%
for i in range(len(confnorm)):
    print(classes[i],confnorm[i,i])
# Out:
# 32PSK 0.738748536054877
# 16APSK 0.689906260462002
# 32QAM 0.6564569536423841
# FM 0.7225902616760517
# GMSK 0.6616898823921928
# 32APSK 0.6038631254683207
# OQPSK 0.5560613724498398
# 8ASK 0.5418109846610589
# BPSK 0.6153334994600881
# 8PSK 0.6401747458623877
# AM-SSB-SC 0.5445969847553273
# 4ASK 0.5767102615694165
# 16PSK 0.5902189413639796
# 64APSK 0.5479349809255266
# 128QAM 0.478718118582312
# 128APSK 0.4621224762222593
# AM-DSB-SC 0.5171347375459713
# AM-SSB-WC 0.46744224974891196
# 64QAM 0.45280538897560174
# QPSK 0.5675386640342218
# 256QAM 0.7238567585743106
# AM-DSB-WC 0.818815331010453
# OOK 0.6959859801385296
# 16QAM 0.6619706568856285

# %%
acc={}
Z_test = Z[test_idx]
Z_test = Z_test.reshape((len(Z_test)))
SNRs = np.unique(Z_test)
for snr in SNRs:
    X_test_snr = X_test[Z_test==snr]
    Y_test_snr = Y_test[Z_test==snr]
    
    pre_Y_test = model.predict(X_test_snr)
    conf = np.zeros([len(classes),len(classes)])
    confnorm = np.zeros([len(classes),len(classes)])
    for i in range(0,X_test_snr.shape[0]):    #该信噪比下测试数据量
        j = list(Y_test_snr[i,:]).index(1)   #正确类别下标
        k = int(np.argmax(pre_Y_test[i,:])) #预测类别下标
        conf[j,k] = conf[j,k] + 1
    for i in range(0,len(classes)):
        confnorm[i,:] = conf[i,:] / np.sum(conf[i,:])
   
    plt.figure()
    plot_confusion_matrix(confnorm, labels=classes, title="ConvNet Confusion Matrix (SNR=%d)"%(snr))
    
    cor = np.sum(np.diag(conf))
    ncor = np.sum(conf) - cor
    print ("Overall Accuracy %s: "%snr, cor / (cor+ncor))
    acc[snr] = 1.0*cor/(cor+ncor)
# Out:
# Overall Accuracy -20:  0.05263643067846608
# Overall Accuracy -18:  0.05320625520495975
# Overall Accuracy -16:  0.0544823288524882
# Overall Accuracy -14:  0.05622526916352259
# Overall Accuracy -12:  0.06725438516768154
# Overall Accuracy -10:  0.09017945711966814
# Overall Accuracy -8:  0.13391608391608392
# Overall Accuracy -6:  0.22576777644563312
# Overall Accuracy -4:  0.33932564171362134
# Overall Accuracy -2:  0.47821494586744123
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Overall Accuracy 0:  0.5912808988764044
# Overall Accuracy 2:  0.6683933031171955
# Overall Accuracy 4:  0.7660834217037823
# Overall Accuracy 6:  0.8394982012729453
# Overall Accuracy 8:  0.8952672305200647
# Overall Accuracy 10:  0.933649289099526
# Overall Accuracy 12:  0.9442273534635879
# Overall Accuracy 14:  0.9454142421723469
# Overall Accuracy 16:  0.9455072989391604
# Overall Accuracy 18:  0.9508337631081314
# Overall Accuracy 20:  0.9482513758210545
# Overall Accuracy 22:  0.943987429522137
# Overall Accuracy 24:  0.9500220750551877
# Overall Accuracy 26:  0.9473634740107153
# Overall Accuracy 28:  0.9480471628592484
# Overall Accuracy 30:  0.9481520872108482

# %%
plt.plot(acc.keys(),acc.values())
plt.ylabel('ACC')
plt.xlabel('SNR')
plt.grid(True)
plt.show()
